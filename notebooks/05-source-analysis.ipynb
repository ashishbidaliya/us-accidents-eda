# %% [markdown]
# # Source Analysis
#
# In this section:
# 1. Analyze accident data sources
# 2. Compare contribution from different sources

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv(
    "../data/raw/US_Accidents_March23.csv",
    usecols=['Source']
)

# %% [markdown]
# ## Source Value Counts

# %%
df.Source.value_counts()
# Out:
# Source
# Source1    4325632
# Source2    3305373
# Source3      97389
# Name: count, dtype: int64

# %% [markdown]
# ## Source Distribution Pie Chart

# %%
df.Source.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
